# %% [markdown]
# Using pandas, you can read data from csv, excel, json, sql databases among others

# %%
import pandas as pd

# %%
#import the data in the csv file
olympicsDataFrame = pd.read_csv('/home/ajay/Desktop/Ex_Files_Pandas_EssT/ExerciseFiles/data/olympics.csv')

# %% [markdown]
# The skiprows=n parameter allows you to skip the first n rows of the csv table

# %%
#the shape attribute is useful for confirmimg the dimentions of your dataset
olympicsDataFrame.shape
# Out:
# (29216, 10)

# %% [markdown]
# The above output is (number_of_rows, number_of_columns)

# %%
numberOfRows= olympicsDataFrame.shape[0]

# %%
numberOfRows
# Out:
# 29216

# %%
numberOfColumns= olympicsDataFrame.shape[1]

# %%
numberOfColumns
# Out:
# 10

# %%
#The shape attribute returns a tuple
type(olympicsDataFrame.shape)
# Out:
# tuple

# %% [markdown]
# head() and tail() return the first and last N rows of the DataFrame

# %%
#By default n=5
olympicsDataFrame.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
olympicsDataFrame.tail()
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213      NaN     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214      NaN     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215      NaN     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %%
#to display first three rows
olympicsDataFrame.head(3)
# Out:
#      City  Edition     Sport Discipline            Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming      HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming   HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming  DRIVAS, Dimitrios  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze

# %%
#info provides the summary of a DataFrame including the number of enteries, the datatype, and the number of 
#non-null entries for each series in the DataFrame
olympicsDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29213 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB
